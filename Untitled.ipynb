# %%
import pandas as pd

# df = pd.read_csv("loan_approvel_data.csv",sep="\t")
# #df.head()
# grouped=df.groupby("Age")["Applicant_Income"].max()
# grouped
df1 = pd.DataFrame({'A': ['A0', 'A1'], 'B': ['B0', 'B1']})
df2 = pd.DataFrame({'A': ['A2', 'A3'], 'B': ['B2', 'B3']})
concated=pd.concat([df1,df2],axis=1)
concated
# Out:
#     A   B   A   B
# 0  A0  B0  A2  B2
# 1  A1  B1  A3  B3
